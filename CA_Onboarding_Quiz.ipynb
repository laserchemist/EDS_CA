# %% [markdown]
# # 📝 Course Assistant Onboarding Quiz
#
# <div style="background:#fff3cd;border-left:6px solid #ffc107;padding:12px 16px;border-radius:6px;margin:10px 0;">
# <b>Instructions</b>
# <ul>
# <li>This quiz checks your comfort with the coding, data wrangling, statistics, and machine learning
#     content you'll be supporting students on this semester.</li>
# <li><b>30 questions are randomly selected from a bank of 50</b> — every CA sees a different subset,
#     and a different subset again on each retake.</li>
# <li><b>Multiple attempts are allowed</b> (see <code>max_attempts</code> below). Between attempts,
#     review the CA/Fellow manual sections on Coding Review, Data Wrangling, and Statistics for any
#     topic you missed, then retake the quiz — don't just immediately re-click through it.</li>
# <li>Feedback appears immediately after each answer so you can learn from a miss right away.</li>
# <li>Goal: pass with a strong score sometime in your first week, after a review pass or two.</li>
# <li>Click <b>Submit Quiz</b> when finished.</li>
# </ul>
# </div>

# %% [markdown]
# ### Step 1 — Enter your name and run setup

# %%
from lab05_init import *        # loads apply_style, user, etc. -- swap for the CA/staff init module if different
from stemds_quiz import open_quiz

name = "..."                    # ← enter your name here

# %% [markdown]
# ### Step 2 — Run this cell to open your quiz
#
# This draws 30 questions at random from the 50-question bank in `questions_ca_onboarding.json`.
# Up to 3 attempts are allowed — review between attempts rather than immediately retaking.

# %%
result = open_quiz(
    "questions_ca_onboarding.json",
    name, user,
    quiz_id      = "CA_Onboarding",
    max_attempts = 3,            # multiple tries allowed -- adjust to taste
    n_questions  = 30,           # 30 drawn randomly from 50
)

# %% [markdown]
# ### Step 3 — Submit when finished

# %%
from lab_submit_canvas import submit_quiz

score, total = result
submit_quiz(name, user, score, total, quiz_id="CA_Onboarding")
