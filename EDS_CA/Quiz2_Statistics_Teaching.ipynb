# %% [markdown]
# # 📝 CA/Fellow Quiz 2 — Statistics, Strategies &amp; Teaching Foundations
#
# <div style="background:#fff3cd;border-left:6px solid #ffc107;padding:12px 16px;border-radius:6px;margin:10px 0;">
# <b>Instructions</b>
# <ul>
# <li>Covers Sections 4–6 of the CA/Fellow manual: <b>Statistics</b>, <b>Strategies for Success</b>, and
#     <b>Teaching Foundations</b> (motivation, Bloom's taxonomy, teacher-as-leader).</li>
# <li><b>30 questions are randomly selected from a bank of 50</b> each time you open this quiz.</li>
# <li><b>You get 3 attempts at the whole quiz.</b> Each new attempt draws a fresh set of 30 questions —
#     it is not the same 30 again, so re-taking is real practice, not memorization.</li>
# <li><b>Re-running this cell mid-attempt does NOT use up a new attempt</b> — if your kernel restarts partway
#     through, you'll resume exactly where you left off with the same questions.</li>
# <li>A new attempt only starts once you've fully finished the previous one. <b>Review the relevant
#     manual sections between attempts</b> rather than immediately re-opening the quiz.</li>
# <li>Feedback appears immediately after each answer.</li>
# <li>Click <b>Submit Quiz</b> when finished.</li>
# </ul>
# </div>

# %% [markdown]
# ### Step 1 — Enter your name and run setup

# %%
from lab05_init import *        # loads apply_style, user, etc. -- swap for the CA/staff init module if different
from stemds_quiz import open_quiz

name = "..."                    # ← enter your name here

# %% [markdown]
# ### Step 2 — Run this cell to open (or resume) your quiz

# %%
result = open_quiz(
    "questions_quiz2_stats_teaching.json",
    name, user,
    quiz_id           = "CA_Quiz2_StatsTeaching",
    n_questions       = 30,          # 30 drawn randomly from 50, fresh each attempt
    max_quiz_attempts = 3,           # 3 tries at the whole quiz
)

# %% [markdown]
# ### Step 3 — Submit when finished

# %%
from lab_submit_canvas import submit_quiz

score, total = result
submit_quiz(name, user, score, total, quiz_id="CA_Quiz2_StatsTeaching")
